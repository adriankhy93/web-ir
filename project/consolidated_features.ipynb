# %%
import pandas as pd
import string
from rank_bm25 import BM25Okapi

import numpy as np

# %% [markdown]
# # API 1: Given search terms
# - prof_id
# - paper_id

# %%
def replace_punct_with_space(text):
    return text.translate(str.maketrans(string.punctuation, " " * 32))


def replace_multiple_spaces_with_single_space(text):
    return " ".join(text.split())


def preprocess_pipeline(text):
    preproc_text = text.lower()
    preproc_text = replace_punct_with_space(preproc_text)
    preproc_text = replace_multiple_spaces_with_single_space(preproc_text)
    return preproc_text


def prepare_prof_info():
    prof_info_df = pd.read_csv("data/prof_info.csv")
    prof_info_df["preproc_name"] = prof_info_df["name"].apply(
        lambda x: preprocess_pipeline(x)
    )
    prof_info_df["preproc_area_of_interest"] = prof_info_df["area_of_interest"].apply(
        lambda x: preprocess_pipeline(x)
    )
    return prof_info_df


def get_id_to_name(prof_info_df):
    # map prof_id to prof name
    id_list = prof_info_df["id"].tolist()
    name_list = prof_info_df["name"].tolist()
    id_to_name = dict(map(lambda i, j: (i, j), id_list, name_list))
    return id_to_name


def prepare_paper_data():
    paper_data_w_abstract_df = pd.read_csv("data/paper_data_NEW.csv")
    paper_data_w_abstract_df["preproc_title"] = paper_data_w_abstract_df[
        "paper_title"
    ].apply(lambda x: preprocess_pipeline(x))

    paper_data_w_abstract_df["preproc_abstract"] = (
        paper_data_w_abstract_df["paper_abstract"]
        .fillna("")
        .apply(lambda x: preprocess_pipeline(x))
    )

    ## construct doc corpus
    #   join title, abstract

    paper_data_w_abstract_df["corpus"] = (
        paper_data_w_abstract_df["preproc_title"]
        + " "
        + paper_data_w_abstract_df["preproc_abstract"]
    )

    return paper_data_w_abstract_df


def init_search_engine(corpus):
    tokenized_corpus = [doc.split(" ") for doc in corpus]
    bm25 = BM25Okapi(tokenized_corpus)
    return bm25


def prepare_search_engine(prof_info_df, paper_data_w_abstract_df):
    id_to_name = get_id_to_name(prof_info_df)

    corpus = paper_data_w_abstract_df["corpus"].tolist()
    search_engine = init_search_engine(corpus)

    return search_engine, id_to_name


def get_relevant_documents_indexes(search_engine, query, k):
    # Get the top k indexes
    query = preprocess_pipeline(query)
    tokenized_query = query.split(" ")

    doc_scores = search_engine.get_scores(tokenized_query)
    num_of_rel_docs = sum(doc_scores != 0)
    k = min(num_of_rel_docs, k)

    top_k_indexs = np.argsort(doc_scores)[::-1][:k]
    return top_k_indexs


def get_all_relevant_info(top_k_indexes, prof_info_df, paper_data_w_abstract_df):
    extracted_prof_ids = paper_data_w_abstract_df.loc[top_k_indexes, "prof_id"]

    extracted_paper_data = paper_data_w_abstract_df.loc[
        top_k_indexes, ["title", "link", "snippet", "abstract"]
    ]

    extracted_prof_info = prof_info_df.loc[
        extracted_prof_ids, ["title", "name", "email", "link", "area_of_interest"]
    ]

    return extracted_paper_data, extracted_prof_info


def search_pipeline(prof_info_df, paper_data_w_abstract_df, search_engine, query, k):
    top_k_indexes = get_relevant_documents_indexes(search_engine, query, k)
    extracted_paper_data, extracted_prof_info = get_all_relevant_info(
        top_k_indexes, prof_info_df, paper_data_w_abstract_df
    )
    return extracted_paper_data, extracted_prof_info


def search_pipeline_indexes(
    prof_info_df, paper_data_w_abstract_df, search_engine, query, k
):
    top_k_indexes = get_relevant_documents_indexes(search_engine, query, k)
    return top_k_indexes.tolist()

# %%
prof_info_df = prepare_prof_info()
paper_data_w_abstract_df = prepare_paper_data()
search_engine, id_to_name = prepare_search_engine(
    prof_info_df, paper_data_w_abstract_df
)

# %%
query = "variational inference"
doc_ids = search_pipeline_indexes(
    prof_info_df, paper_data_w_abstract_df, search_engine, query, k=20
)

# %%
prof_ids = paper_data_w_abstract_df.loc[doc_ids, "prof_id"].tolist()

# %%
N = len(doc_ids)
json_output = [{"doc_id": doc_ids[i], "prof_id": prof_ids[i]} for i in range(N)]

# %%
import json

json_output = json.dumps(json_output)

# %%
json_output
# Out:
# '[{"doc_id": 1171, "prof_id": 25}, {"doc_id": 1028, "prof_id": 21}, {"doc_id": 38, "prof_id": 2}, {"doc_id": 41, "prof_id": 2}, {"doc_id": 44, "prof_id": 2}, {"doc_id": 42, "prof_id": 2}, {"doc_id": 1693, "prof_id": 36}, {"doc_id": 24, "prof_id": 2}, {"doc_id": 1689, "prof_id": 36}, {"doc_id": 452, "prof_id": 10}, {"doc_id": 1527, "prof_id": 33}, {"doc_id": 1167, "prof_id": 25}, {"doc_id": 45, "prof_id": 2}, {"doc_id": 1518, "prof_id": 33}, {"doc_id": 912, "prof_id": 17}, {"doc_id": 532, "prof_id": 11}, {"doc_id": 1215, "prof_id": 25}, {"doc_id": 1112, "prof_id": 23}, {"doc_id": 1022, "prof_id": 21}, {"doc_id": 816, "prof_id": 15}]'

# %% [markdown]
# # API 2: Given prof_id
# - name
# - email
# - area of interest

# %%
prof_info_df.loc[prof_ids, ["name", "title", "email", "area_of_interest", "link"]]
# Out:
#             name                title                        email  \
# 25   Maosong Sun            Professor          sms@tsinghua.edu.cn
# 21       Dan Pei  Associate Professor       peidan@tsinghua.edu.cn
# 2   Jianfei Chen  Assistant Professor     jianfeic@tsinghua.edu.cn
# 2   Jianfei Chen  Assistant Professor     jianfeic@tsinghua.edu.cn
# 2   Jianfei Chen  Assistant Professor     jianfeic@tsinghua.edu.cn
# 2   Jianfei Chen  Assistant Professor     jianfeic@tsinghua.edu.cn
# 36       Jun Zhu            Professor        dcszj@tsinghua.edu.cn
# 2   Jianfei Chen  Assistant Professor     jianfeic@tsinghua.edu.cn
# 36       Jun Zhu            Professor        dcszj@tsinghua.edu.cn
# 10  Minlie Huang  Associate Professor      aihuang@tsinghua.edu.cn
# 33     Min Zhang  Associate Professor          z-m@tsinghua.edu.cn
# 25   Maosong Sun            Professor          sms@tsinghua.edu.cn
# 2   Jianfei Chen  Assistant Professor     jianfeic@tsinghua.edu.cn
# 33     Min Zhang  Associate Professor          z-m@tsinghua.edu.cn
# 17   Zhiyuan Liu  Associate Professor        liuzy@tsinghua.edu.cn
# 11  Zhengfeng Ji            Professor  jizhengfeng@tsinghua.edu.cn
# 25   Maosong Sun            Professor          sms@tsinghua.edu.cn
# 23    Fuchun Sun            Professor        fcsun@tsinghua.edu.cn
# 21       Dan Pei  Associate Professor       peidan@tsinghua.edu.cn
# 15      Yang Liu            Professor  liuyang2011@tsinghua.edu.cn
#
#                                      area_of_interest  \
# 25  Artificial intelligence, deep learning, natura...
# 21  Data Mining, Autonomous IT Operations, AIOps (...
# 2                                       Deep Learning
# 2                                       Deep Learning
# 2                                       Deep Learning
# 2                                       Deep Learning
# 36                                   Machine Learning
# 2                                       Deep Learning
# 36                                   Machine Learning
# 10  Machine learning applications, deep learning, ...
# 33  Information Retrieval, User Behavior Analysis,...
# 25  Artificial intelligence, deep learning, natura...
# 2                                       Deep Learning
# 33  Information Retrieval, User Behavior Analysis,...
# 17  Social Computation, Knowledge Graphs, natural ...
# 11           Quantum computing, Theory of computation
# 25  Artificial intelligence, deep learning, natura...
# 23  Active Sensing and Dexterious Operations, Cros...
# 21  Data Mining, Autonomous IT Operations, AIOps (...
# 15   natural language processing, Machine Translation
#
#                                                  link
# 25  http://www.cs.tsinghua.edu.cn/publish/csen/462...
# 21                  https://netman.aiops.org/~peidan/
# 2             https://ml.cs.tsinghua.edu.cn/~jianfei/
# 2             https://ml.cs.tsinghua.edu.cn/~jianfei/
# 2             https://ml.cs.tsinghua.edu.cn/~jianfei/
# 2             https://ml.cs.tsinghua.edu.cn/~jianfei/
# 36      http://ml.cs.tsinghua.edu.cn/~jun/index.shtml
# 2             https://ml.cs.tsinghua.edu.cn/~jianfei/
# 36      http://ml.cs.tsinghua.edu.cn/~jun/index.shtml
# 10                 http://coai.cs.tsinghua.edu.cn/hml
# 33                 http://www.thuir.cn/group/~mzhang/
# 25  http://www.cs.tsinghua.edu.cn/publish/csen/462...
# 2             https://ml.cs.tsinghua.edu.cn/~jianfei/
# 33                 http://www.thuir.cn/group/~mzhang/
# 17              http://nlp.csai.tsinghua.edu.cn/~lzy/
# 11  https://www.cs.tsinghua.edu.cn/info/1121/4990.htm
# 25  http://www.cs.tsinghua.edu.cn/publish/csen/462...
# 23  http://www.cs.tsinghua.edu.cn/publish/csen/462...
# 21                  https://netman.aiops.org/~peidan/
# 15               http://nlp.csai.tsinghua.edu.cn/~ly/

# %% [markdown]
# # API 2: Given doc_id
# - title
# - abstract
# - link

# %%
paper_data_w_abstract_df
# Out:
#       prof_id                        paper_link  \
# 0           1  https://arxiv.org/abs/2304.02948
# 1           1  https://arxiv.org/abs/2303.02635
# 2           1  https://arxiv.org/abs/2212.02122
# 3           1  https://arxiv.org/abs/2209.08455
# 4           1  https://arxiv.org/abs/2209.06122
# ...       ...                               ...
# 1888       38  https://arxiv.org/abs/2201.02658
# 1889       38  https://arxiv.org/abs/2112.12896
# 1890       38  https://arxiv.org/abs/2112.12251
# 1891       38  https://arxiv.org/abs/2112.07835
# 1892       38  https://arxiv.org/abs/2112.05372
#
#                                             paper_title  \
# 0     FengWu: Pushing the Skillful Global Medium-ran...
# 1     VTQA: Visual Text Question Answering via Entit...
# 2     CLIPVG: Text-Guided Image Manipulation Using D...
# 3     TODE-Trans: Transparent Object Depth Estimatio...
# 4     What You See is What You Grasp: User-Friendly ...
# ...                                                 ...
# 1888  Fair and efficient contribution valuation for ...
# 1889  Dewetting Characteristics of Contact Lenses Co...
# 1890  ML4CO: Is GCNN All You Need? Graph Convolution...
# 1891  Mining Minority-class Examples With Uncertaint...
# 1892  A recurrent neural network approach for remain...
#
#                                          paper_abstract  \
# 0     We present FengWu, an advanced data-driven glo...
# 1     The ideal form of Visual Question Answering re...
# 2     Considerable progress has recently been made i...
# 3     Transparent objects are widely used in industr...
# 4     This work presents a next-generation human-rob...
# ...                                                 ...
# 1888  Federated learning is a popular technology for...
# 1889  Hypothesis:\n  Although wetting agents have be...
# 1890  The 2021 NeurIPS Machine Learning for Combinat...
# 1891  In the real world, the frequency of occurrence...
# 1892  Data-driven methods for remaining useful life ...
#
#                                           preproc_title  \
# 0     fengwu pushing the skillful global medium rang...
# 1     vtqa visual text question answering via entity...
# 2     clipvg text guided image manipulation using di...
# 3     tode trans transparent object depth estimation...
# 4     what you see is what you grasp user friendly g...
# ...                                                 ...
# 1888  fair and efficient contribution valuation for ...
# 1889  dewetting characteristics of contact lenses co...
# 1890  ml4co is gcnn all you need graph convolutional...
# 1891  mining minority class examples with uncertaint...
# 1892  a recurrent neural network approach for remain...
#
#                                        preproc_abstract  \
# 0     we present fengwu an advanced data driven glob...
# 1     the ideal form of visual question answering re...
# 2     considerable progress has recently been made i...
# 3     transparent objects are widely used in industr...
# 4     this work presents a next generation human rob...
# ...                                                 ...
# 1888  federated learning is a popular technology for...
# 1889  hypothesis although wetting agents have been d...
# 1890  the 2021 neurips machine learning for combinat...
# 1891  in the real world the frequency of occurrence ...
# 1892  data driven methods for remaining useful life ...
#
#                                                  corpus
# 0     fengwu pushing the skillful global medium rang...
# 1     vtqa visual text question answering via entity...
# 2     clipvg text guided image manipulation using di...
# 3     tode trans transparent object depth estimation...
# 4     what you see is what you grasp user friendly g...
# ...                                                 ...
# 1888  fair and efficient contribution valuation for ...
# 1889  dewetting characteristics of contact lenses co...
# 1890  ml4co is gcnn all you need graph convolutional...
# 1891  mining minority class examples with uncertaint...
# 1892  a recurrent neural network approach for remain...
#
# [1893 rows x 7 columns]

# %%
paper_data_w_abstract_df.loc[doc_ids, ["paper_title", "paper_abstract", "paper_link"]]
# Out:
#                                             paper_title  \
# 1171  Fuse It More Deeply! A Variational Transformer...
# 1028  On the Necessity and Effectiveness of Learning...
# 38    VFlow: More Expressive Generative Flows with V...
# 41        ZhuSuan: A Library for Bayesian Deep Learning
# 44                      Scaling up Dynamic Topic Models
# 42    Scalable Inference for Nested Chinese Restaura...
# 1693  Improved Techniques for Maximum Likelihood Est...
# 24    Improved Techniques for Maximum Likelihood Est...
# 1689  ProlificDreamer: High-Fidelity and Diverse Tex...
# 452   DiscoDVT: Generating Long Text with Discourse-...
# 1527  Solving polynomial variational inequality prob...
# 1167  Recurrence Boosts Diversity! Revisiting Recurr...
# 45               Streaming Gibbs Sampling for LDA Model
# 1518  Can Diffusion Model Achieve Better Performance...
# 912   Human Emotion Knowledge Representation Emerges...
# 532   Discontinuity of Maximum Entropy Inference and...
# 1215  TR-BERT: Dynamic Token Reduction for Accelerat...
# 1112  Learning and Inferring Movement with Deep Gene...
# 1022  Causal Inference-Based Root Cause Analysis for...
# 816   FedMR: Federated Learning via Model Recombination
#
#                                          paper_abstract  \
# 1171  The past several years have witnessed Variatio...
# 1028  Using powerful posterior distributions is a po...
# 38    Generative flows are promising tractable model...
# 41    In this paper we introduce ZhuSuan, a python p...
# 44    Dynamic topic models (DTMs) are very effective...
# 42    Nested Chinese Restaurant Process (nCRP) topic...
# 1693  Diffusion models have exhibited excellent perf...
# 24    Diffusion models have exhibited excellent perf...
# 1689  Score distillation sampling (SDS) has shown gr...
# 452   Despite the recent advances in applying pre-tr...
# 1527  In this paper, we study variational inequality...
# 1167  Variational Auto-Encoder (VAE) has been widely...
# 45    Streaming variational Bayes (SVB) is successfu...
# 1518  Diffusion models have been successfully adapte...
# 912   How humans infer discrete emotions is a fundam...
# 532   In this paper, we discuss the connection betwe...
# 1215  Existing pre-trained language models (PLMs) ar...
# 1112  Learning and inference movement is a very chal...
# 1022  Fault diagnosis is critical in many domains, a...
# 816   Although Federated Learning (FL) enables globa...
#
#                             paper_link
# 1171  https://arxiv.org/abs/2207.06130
# 1028  https://arxiv.org/abs/1905.13452
# 38    https://arxiv.org/abs/2002.09741
# 41    https://arxiv.org/abs/1709.05870
# 44    https://arxiv.org/abs/1602.06049
# 42    https://arxiv.org/abs/1702.07083
# 1693  https://arxiv.org/abs/2305.03935
# 24    https://arxiv.org/abs/2305.03935
# 1689  https://arxiv.org/abs/2305.16213
# 452   https://arxiv.org/abs/2110.05999
# 1527  https://arxiv.org/abs/2303.12036
# 1167  https://arxiv.org/abs/2210.12409
# 45    https://arxiv.org/abs/1601.01142
# 1518  https://arxiv.org/abs/2305.04465
# 912   https://arxiv.org/abs/2302.09582
# 532    https://arxiv.org/abs/1406.5046
# 1215  https://arxiv.org/abs/2105.11618
# 1112  https://arxiv.org/abs/1805.07252
# 1022  https://arxiv.org/abs/2206.05871
# 816   https://arxiv.org/abs/2305.10730

# %%
query = "diffusion model"

# %%
def search_pipeline_indexes(search_engine, query, k):
    top_k_indexes = get_relevant_documents_indexes(search_engine, query, k)
    return top_k_indexes.tolist()
k = 20
doc_ids = search_pipeline_indexes(search_engine, query, k=k)
prof_ids = paper_data_w_abstract_df.loc[doc_ids, "prof_id"].tolist()

prof_names = prof_info_df.loc[prof_ids, "name"].tolist()
prof_links = prof_info_df.loc[prof_ids, "link"].tolist()

paper_titles = paper_data_w_abstract_df.loc[doc_ids, "paper_title"].tolist()
paper_abstracts = paper_data_w_abstract_df.loc[doc_ids, "paper_abstract"].tolist()
paper_links = paper_data_w_abstract_df.loc[doc_ids, "paper_link"].tolist()
# prof_info_df.loc[prof_ids, ["name", "title", "email", "area_of_interest", "link"]]
# paper_data_w_abstract_df.loc[doc_ids, ["title", "abstract", "link"]]

N = len(doc_ids)
json_output = [
    {
        "rank": i,
        "prof_name": prof_names[i],
        "prof_link": prof_links[i],
        "paper_title": paper_titles[i],
        "paper_abstract": paper_abstracts[i],
        "paper_link": paper_links[i],
    }
    for i in range(N)
]
# json_output = json.dumps(json_output)

# %%
##get unique paper titles
unique_paper_titles = []
for title in paper_titles:
    if title not in unique_paper_titles:
        unique_paper_titles.append(title)

# %%
for unique_title in unique_paper_titles:
    for title in paper_titles:
# Out:
# ['Robust Classification via a Single Diffusion Model',
#  'Locally Attentional SDF Diffusion for Controllable 3D Shape Generation',
#  'One Transformer Fits All Distributions in Multi-Modal Diffusion at Scale',
#  'Improved Techniques for Maximum Likelihood Estimation for Diffusion ODEs',
#  'Improved Techniques for Maximum Likelihood Estimation for Diffusion ODEs',
#  'Pattern Formation in a Coupled Membrane-Bulk Reaction-Diffusion Model for Intracellular Polarization and Oscillations',
#  'Analog Bits: Generating Discrete Data using Diffusion Models with Self-Conditioning',
#  'Efficient Cross-Lingual Transfer for Chinese Stable Diffusion with Images as Pivots',
#  'Efficient Cross-Lingual Transfer for Chinese Stable Diffusion with Images as Pivots',
#  'All are Worth Words: A ViT Backbone for Diffusion Models',
#  'DPM-Solver: A Fast ODE Solver for Diffusion Probabilistic Model Sampling in Around 10 Steps',
#  'DPM-Solver: A Fast ODE Solver for Diffusion Probabilistic Model Sampling in Around 10 Steps',
#  'A Closer Look at Parameter-Efficient Tuning in Diffusion Models',
#  'Latent Video Diffusion Models for High-Fidelity Long Video Generation',
#  'Can Diffusion Model Achieve Better Performance in Text Generation? Bridging the Gap between Training and Inference!',
#  'Maximum Likelihood Training for Score-Based Diffusion ODEs by High-Order Denoising Score Matching',
#  'Maximum Likelihood Training for Score-Based Diffusion ODEs by High-Order Denoising Score Matching',
#  'Effect of surface H$_2$ on molecular hydrogen formation on interstellar grains',
#  'DPM-Solver++: Fast Solver for Guided Sampling of Diffusion Probabilistic Models',
#  'DPM-Solver++: Fast Solver for Guided Sampling of Diffusion Probabilistic Models']

# %%
unique_paper_titles
# Out:
# ['Robust Classification via a Single Diffusion Model',
#  'Locally Attentional SDF Diffusion for Controllable 3D Shape Generation',
#  'One Transformer Fits All Distributions in Multi-Modal Diffusion at Scale',
#  'Improved Techniques for Maximum Likelihood Estimation for Diffusion ODEs',
#  'Pattern Formation in a Coupled Membrane-Bulk Reaction-Diffusion Model for Intracellular Polarization and Oscillations',
#  'Analog Bits: Generating Discrete Data using Diffusion Models with Self-Conditioning',
#  'Efficient Cross-Lingual Transfer for Chinese Stable Diffusion with Images as Pivots',
#  'All are Worth Words: A ViT Backbone for Diffusion Models',
#  'DPM-Solver: A Fast ODE Solver for Diffusion Probabilistic Model Sampling in Around 10 Steps',
#  'A Closer Look at Parameter-Efficient Tuning in Diffusion Models',
#  'Latent Video Diffusion Models for High-Fidelity Long Video Generation',
#  'Can Diffusion Model Achieve Better Performance in Text Generation? Bridging the Gap between Training and Inference!',
#  'Maximum Likelihood Training for Score-Based Diffusion ODEs by High-Order Denoising Score Matching',
#  'Effect of surface H$_2$ on molecular hydrogen formation on interstellar grains',
#  'DPM-Solver++: Fast Solver for Guided Sampling of Diffusion Probabilistic Models']
